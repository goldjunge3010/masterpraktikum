# %% [markdown]
# ### DeepLC first tryout

# %% [markdown]
# Install via conda does not seem to work -> failed solve
# Installation via pip worked

# %%
import pandas as pd
from deeplc import DeepLC

peptide_file = "data/datasets/test_pred.csv"
calibration_file = "data/datasets/test_train.csv"

pep_df = pd.read_csv(peptide_file, sep=",")
pep_df['modifications'] = pep_df['modifications'].fillna("")

cal_df = pd.read_csv(calibration_file, sep=",")
cal_df['modifications'] = cal_df['modifications'].fillna("")

dlc = DeepLC()
dlc.calibrate_preds(seq_df=cal_df)
preds = dlc.make_preds(seq_df=pep_df)
# Out:
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 819ms/step
# 1/1 [==============================] - 1s 642ms/step
# 1/1 [==============================] - 1s 638ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f02596e8b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 709ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f02596eb910> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 717ms/step
# 1/1 [==============================] - 1s 678ms/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 1s 750ms/step

# %%
preds
# Out:
# array([ 5046.5150937 ,  8075.81447448,  6188.31678343,  6167.79633204,
#         4870.41030456,  4468.3733079 ,  8110.32745386,  5877.40831682,
#         6342.85497359,  4580.26270179,  5732.25632145,  8341.44349998,
#         6058.03618057,  5612.03950858, 10192.25988456,  6066.81409384,
#         4248.50461716,  4895.10435126,  8010.09033373,  4946.80776623,
#         3678.46253023,  5040.03165213,  8573.52564409,  5127.97771673,
#         5997.00685946,  4159.61529515, 10272.77886845,  5585.69042171,
#         6188.1842337 ,  6215.96267461,  6288.86526239,  3452.65150573,
#         5150.55446613,  6614.22691904,  2861.67155802,  2845.50650252,
#         6859.41945822,  6354.9342146 ,  6456.22925834,  8402.34741102,
#         8268.96125302,  9403.94141603,  5180.36520411,  7069.26028669,
#         2889.60401347,  4225.086617  ,  6050.43452194,  9238.19801629,
#         5274.43725637,  5482.46294662,  8727.27740872,  8843.08472452,
#         5590.07094045, 10016.55619537,  7706.28953595,  6981.58909438,
#         5462.07866138,  5268.33195731,  5260.21452684,  6701.92072557,
#         3854.90064292,  4265.21791732,  6943.12887208,  4336.16732039,
#         5780.29675502,  7447.84312006, 10193.33107746,  4602.43989069,
#         8430.90699043,  5512.96632361,  3366.83721785,  4929.65809855,
#         7680.64605546, 10137.92754872,  4770.02919095,  3164.67034012,
#         3678.56947339,  5856.75097611,  6220.26265149,  4389.2022714 ,
#        10097.61179225,  8090.54626746,  5299.19072588,  5035.54425331,
#         8288.42779763,  9313.81140341,  9957.89855291,  3072.11521022,
#         5667.10650467,  5536.08736061,  7096.82711833, 11037.76170118,
#         3064.211521  ,  3785.57716806,  9488.43702373,  6111.65407022,
#         5414.24098524,  6846.74905299, 10186.22147656,  6114.32479763,
#         9784.58173697, 10179.90243429,  5276.75189413,  7306.77348168,
#         6654.11263674, 10548.41168213,  8004.01997029,  6736.53334049,
#        12117.40315128,  5233.73226028,  9189.80205279,  3642.73687393,
#         7342.22973148, 10984.84574674,  7612.13561298,  7690.82155838,
#         5387.53141359,  4883.86279772,  5619.047358  ,  4728.09985602,
#         7574.19585872,  3553.09592415,  7959.44953583,  7511.96987776,
#         3025.72912888,  3518.49957154,  7021.74407053,  4810.13279717,
#         6730.09649476, 10685.26972918,  6588.21814232,  5248.92179152,
#         7679.19919144,  5020.39557621, 10215.21392215, 12887.58883345,
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 53
#      50 df["tr"] = df["tr"]**0.85
#      52 # Calibrate the original model based on the new retention times
# ---> 53 dlc.calibrate_preds(seq_df=df)
#      55 print("a")
#      57 # Make predictions; calibrated and uncalibrated
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/deeplc/deeplc.py:986, in DeepLC.calibrate_preds(self, psm_list, infile, measured_tr, correction_factor, location_peprec_retraining, location_retraining_models, psm_utils_obj, sample_for_calibration_curve, seq_df, use_median)
#     984     logger.debug("Trying out the following model: %s" % (m))
#     985 if self.pygam_calibration:
# --> 986     calibrate_output = self.calibrate_preds_func_pygam(
#     987         psm_list,
#     988         measured_tr=measured_tr,
#     989         correction_factor=correction_factor,
#     990         seq_df=seq_df,
#     991         use_median=use_median,
#     992         mod_name=m,
#     993     )
#     994 else:
#     995     calibrate_output = self.calibrate_preds_func(
#     996         psm_list,
#     997         measured_tr=measured_tr,
#    (...)
#    1001         mod_name=m,
#    1002     )
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/deeplc/deeplc.py:697, in DeepLC.calibrate_preds_func_pygam(self, psm_list, correction_factor, seq_df, measured_tr, use_median, mod_name)
#     693     psm_list = PSMList(psm_list=list_of_psms)
#     695     measured_tr = [psm.retention_time for psm in psm_list]
# --> 697 predicted_tr = self.make_preds(
#     698     psm_list,
#     699     calibrate=False,
#     700     mod_name=mod_name)
#     702 # sort two lists, predicted and observed based on measured tr
#     703 tr_sort = [
#     704     (mtr, ptr)
#     705     for mtr, ptr in sorted(
#     706         zip(measured_tr, predicted_tr), key=lambda pair: pair[1]
#     707     )
#     708 ]
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/deeplc/deeplc.py:655, in DeepLC.make_preds(self, psm_list, infile, calibrate, seq_df, mod_name)
#     653     ret_preds = np.array([sum(a)/len(a) for a in zip(*ret_preds)])
#     654 elif mod_name is not None:
# --> 655     ret_preds = self.make_preds_core(X=X,
#     656                                      X_sum=X_sum,
#     657                                      X_global=X_global,
#     658                                      X_hc=X_hc,
#     659                                      calibrate=calibrate,
#     660                                      mod_name=mod_name)
#     661 elif isinstance(self.model, list):
#     662     for m_name in self.model:
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/deeplc/deeplc.py:562, in DeepLC.make_preds_core(self, X, X_sum, X_global, X_hc, psm_list, calibrate, mod_name)
#     558     return []
#     560 ret_preds = []
# --> 562 mod = load_model(
#     563             mod_name,
#     564             custom_objects={'<lambda>': lrelu}
#     565         )
#     566 try:
#     567     X
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/mp/lib/python3.10/site-packages/keras/saving/legacy/save.py:227, in load_model(filepath, custom_objects, compile, options)
#     225 if isinstance(filepath_str, str):
#     226     if not tf.io.gfile.exists(filepath_str):
# --> 227         raise IOError(
#     228             f"No file or directory found at {filepath_str}"
#     229         )
#     231     if tf.io.gfile.isdir(filepath_str):
#     232         return saved_model_load.load(
#     233             filepath_str, compile, options
#     234         )
#
# OSError: No file or directory found at deeplc/mods/full_hc_hela_hf_psms_aligned_1fd8363d9af9dcad3be7553c39396960.hdf5
