# %%
# install necessary packages
# !python -m pip install -q dlomix==0.0.4
# !python -m pip install -q wandb
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 42.4 MB/s eta 0:00:00
#   Building wheel for fpdf (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.7 requires jax>=0.4.6, but you have jax 0.3.25 which is incompatible.
# flax 0.6.11 requires jax>=0.4.2, but you have jax 0.3.25 which is incompatible.
# orbax-checkpoint 0.2.7 requires jax>=0.4.9, but you have jax 0.3.25 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.7/214.7 kB 18.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.2 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done

# %%
# import necessary packages
import numpy as np
import pandas as pd
import tensorflow as tf
import re

import wandb
from wandb.keras import WandbCallback
from wandb.keras import WandbMetricsLogger
import wandb.apis.reports as wr

import dlomix
from dlomix import constants, data, eval, layers, models, pipelines, reports, utils
from dlomix.data import RetentionTimeDataset
from dlomix.models import PrositRetentionTimePredictor
from dlomix.eval import TimeDeltaMetric
# Out:
# wandb: Thanks for trying out the Report API!
# wandb: For a tutorial, check out https://colab.research.google.com/drive/1CzyJx1nuOS4pdkXa2XPaRQyZdmFmLmXV
# wandb:
# wandb: Try out tab completion to see what's available.
# wandb:   ∟ everything:    `wr.<tab>`
# wandb:       ∟ panels:    `wr.panels.<tab>`
# wandb:       ∟ blocks:    `wr.blocks.<tab>`
# wandb:       ∟ helpers:   `wr.helpers.<tab>`
# wandb:       ∟ templates: `wr.templates.<tab>`
# wandb:
# wandb: For bugs/feature requests, please create an issue on github: https://github.com/wandb/wandb/issues

# %%
# load small train dataset
TRAIN_DATAPATH = 'https://raw.githubusercontent.com/goldjunge3010/masterpraktikum/main/third_pool_tresh_1_0_train.csv'
#TRAIN_DATAPATH = 'https://raw.githubusercontent.com/wilhelm-lab/dlomix/develop/example_dataset/proteomTools_train_val.csv'
BATCH_SIZE = 64

# create dataset
rtdata = RetentionTimeDataset(data_source=TRAIN_DATAPATH,
                              seq_length=30, batch_size=BATCH_SIZE, val_ratio=0.2, test=False, sequence_col= "sequence", target_col= "irt")

print(f"Batch size: {rtdata.batch_size}")
print(f"Number training samples : {len(rtdata.train_data) * rtdata.batch_size}")
print(f"Number validation samples : {len(rtdata.val_data) * rtdata.batch_size}")
# Out:
# Batch size: 64
# Number training samples : 1088
# Number validation samples : 320

# %%
# Initialize WANDB
PROJECT = 'retention_time_report'
RUN = "run_7"
wandb.init(project = PROJECT, name = RUN)

# create report
report = wr.Report(project = PROJECT,
                   title = "Retention time report_data",
                   description = "A first try creating a WANDB report using DLOmix")
report.save()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.5
# Run data is saved locally in <code>/content/wandb/run-20230713_140119-nfezk00h</code>
# Syncing run <strong><a href='https://wandb.ai/master_praktikum/retention_time_report/runs/nfezk00h' target="_blank">run_7</a></strong> to <a href='https://wandb.ai/master_praktikum/retention_time_report' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/master_praktikum/retention_time_report' target="_blank">https://wandb.ai/master_praktikum/retention_time_report</a>
#  View run at <a href='https://wandb.ai/master_praktikum/retention_time_report/runs/nfezk00h' target="_blank">https://wandb.ai/master_praktikum/retention_time_report/runs/nfezk00h</a>
# Report(project='retention_time_report', entity='master_praktikum', title='Retention time report_data', description='A first try creating a WANDB report using DLOmix', width='readable')

# %%
# function to count sequence length
def count_seq_length(df: pd.DataFrame, seq_col: str) -> pd.Series:
    pattern = re.compile(r"\[UNIMOD:.*\]", re.IGNORECASE)
    df[seq_col].replace(pattern, "", inplace= True)
    return df[seq_col].str.len()

# %%
counts = count_seq_length(pd.read_csv(TRAIN_DATAPATH), "sequence")

# %%
c = counts.to_list()
data = [[s] for s in c]
table = wandb.Table(data=data, columns=["scores"])
wandb.log({'my_histogram': wandb.plot.histogram(table, "scores",
 	  title="Sequence length distribution")})
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.012 MB of 0.022 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.528234…
#  View run <strong style="color:#cdcd00">run_3</strong> at: <a href='https://wandb.ai/master_praktikum/retention_time_report/runs/0rpj1bhr' target="_blank">https://wandb.ai/master_praktikum/retention_time_report/runs/0rpj1bhr</a><br/>Synced 4 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230710_075915-0rpj1bhr/logs</code>

# %%
# WORKS!
c = counts.to_list()
data = [[s] for s in c]
table = wandb.Table(data=data, columns=["scores"])
hist = wandb.plot_table(
    vega_spec_name="wandb/simple_hist",
    data_table = table,
    fields = "scores")
wandb.log({'my_histogram': hist})

pg_val = wr.PanelGrid(
    runsets=[
        wr.Runset(ENTITY, PROJECT),
    ],
    panels=[
        wr.CustomChart().from_table(
          table,
        chart_fields = {"fields": "scores"}
)
    ]
)


wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.022 MB of 0.031 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.701718…
#  View run <strong style="color:#cdcd00">run_7</strong> at: <a href='https://wandb.ai/master_praktikum/retention_time_report/runs/vcxwk4d5' target="_blank">https://wandb.ai/master_praktikum/retention_time_report/runs/vcxwk4d5</a><br/>Synced 4 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230710_092516-vcxwk4d5/logs</code>

# %%
c = counts.to_list()
data = [[s] for s in c]
custom_histogram = wandb.plot_table(
    vega_spec_name="wandb/simple_hist",
    data_table = table,
    fields = "scores")
wandb.log({"custom_id" : custom_histogram})
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-3b5b2168d96b> in <cell line: 7>()
#       5     data_table = table,
#       6     fields = "scores")
# ----> 7 wandb.log({"custom_id" : custom_histogram})
#
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py in wrapper(self, *args, **kwargs)
#     387                     return cls.Dummy()
#     388
# --> 389             return func(self, *args, **kwargs)
#     390
#     391         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py in wrapper_fn(self, *args, **kwargs)
#     338             def wrapper_fn(self: Type["Run"], *args: Any, **kwargs: Any) -> Any:
#     339                 if not getattr(self, "_is_finished", False):
# --> 340                     return func(self, *args, **kwargs)
#     341
#     342                 default_message = (
#
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py in wrapper(self, *args, **kwargs)
#     328                     raise e
#     329                 cls._is_attaching = ""
# --> 330             return func(self, *args, **kwargs)
#     331
#     332         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py in log(self, data, step, commit, sync)
#    1743                 ),
#    1744             )
# -> 1745         self._log(data=data, step=step, commit=commit)
#    1746
#    1747     @_run_decorator._noop_on_finish()
#
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py in _log(self, data, step, commit)
#    1524             raise ValueError("Key values passed to `wandb.log` must be strings.")
#    1525
# -> 1526         self._partial_history_callback(data, step, commit)
#    1527
#    1528         if step is not None:
#
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py in _partial_history_callback(self, row, step, commit)
#    1394             not_using_tensorboard = len(wandb.patched["tensorboard"]) == 0
#    1395
# -> 1396             self._backend.interface.publish_partial_history(
#    1397                 row,
#    1398                 user_step=self._step,
#
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/interface/interface.py in publish_partial_history(self, data, user_step, step, flush, publish_step, run)
#     564         run = run or self._run
#     565
# --> 566         data = history_dict_to_json(run, data, step=user_step, ignore_copy_err=True)
#     567         data.pop("_step", None)
#     568
#
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/data_types/utils.py in history_dict_to_json(run, payload, step, ignore_copy_err)
#      50             )
#      51         else:
# ---> 52             payload[key] = val_to_json(
#      53                 run, key, val, namespace=step, ignore_copy_err=ignore_copy_err
#      54             )
#
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/data_types/utils.py in val_to_json(run, key, val, namespace, ignore_copy_err)
#     160                 val.bind_to_run(run, key, namespace)
#     161
# --> 162         return val.to_json(run)
#     163
#     164     return converted  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/wandb/data_types.py in to_json(self, run_or_artifact)
#     625
#     626     def to_json(self, run_or_artifact):
# --> 627         json_dict = super().to_json(run_or_artifact)
#     628
#     629         if isinstance(run_or_artifact, wandb.wandb_sdk.wandb_run.Run):
#
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/data_types/base_types/media.py in to_json(self, run)
#     187
#     188                 assert (
# --> 189                     self._run is run
#     190                 ), "We don't support referring to media files across runs."
#     191
#
# AssertionError: We don't support referring to media files across runs.

# %%
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='12.841 MB of 12.841 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
#  View run <strong style="color:#cdcd00">run_1</strong> at: <a href='https://wandb.ai/master_praktikum/retention_time_report/runs/pln45z59' target="_blank">https://wandb.ai/master_praktikum/retention_time_report/runs/pln45z59</a><br/>Synced 5 W&B file(s), 3 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230709_112943-pln45z59/logs</code>

# %%
c = counts.to_list()
c
# Out:
# [10,
#  11,
#  11,
#  9,
#  11,
#  6,
#  11,
#  9,
#  10,
#  9,
#  11,
#  9,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  8,
#  8,
#  11,
#  9,
#  11,
#  11,
#  10,
#  11,
#  8,
#  11,
#  11,
#  10,
#  4,
#  9,
#  10,
#  10,
#  10,
#  10,
#  11,
#  11,
#  10,
#  8,
#  11,
#  8,
#  2,
#  10,
#  4,
#  9,
#  11,
#  10,
#  8,
#  10,
#  9,
#  10,
#  8,
#  9,
#  11,
#  6,
#  11,
#  9,
#  11,
#  11,
#  10,
#  10,
#  9,
#  10,
#  9,
#  9,
#  9,
#  11,
#  10,
#  11,
#  8,
#  8,
#  4,
#  9,
#  10,
#  11,
#  9,
#  8,
#  10,
#  10,
#  8,
#  10,
#  11,
#  8,
#  8,
#  6,
#  11,
#  11,
#  9,
#  10,
#  11,
#  8,
#  10,
#  11,
#  10,
#  8,
#  9,
#  11,
#  11,
#  9,
#  11,
#  9,
#  8,
#  10,
#  8,
#  8,
#  10,
#  9,
#  11,
#  8,
#  8,
#  8,
#  8,
#  8,
#  6,
#  10,
#  10,
#  9,
#  10,
#  10,
#  4,
#  8,
#  9,
#  8,
#  9,
#  10,
#  10,
#  11,
#  9,
#  4,
#  10,
#  10,
#  10,
#  9,
#  11,
#  8,
#  9,
#  8,
#  11,
#  10,
#  9,
#  8,
#  8,
#  8,
#  9,
#  9,
#  9,
#  11,
#  8,
#  9,
#  11,
#  10,
#  8,
#  8,
#  9,
#  6,
#  9,
#  11,
#  8,
#  9,
#  11,
#  10,
#  9,
#  10,
#  11,
#  8,
#  8,
#  8,
#  9,
#  8,
#  10,
#  9,
#  9,
#  8,
#  10,
#  11,
#  8,
#  9,
#  11,
#  7,
#  8,
#  4,
#  10,
#  10,
#  10,
#  8,
#  9,
#  9,
#  8,
#  8,
#  11,
#  10,
#  8,
#  10,
#  11,
#  9,
#  8,
#  8,
#  8,
#  10,
#  11,
#  9,
#  10,
#  10,
#  9,
#  8,
#  8,
#  8,
#  8,
#  7,
#  10,
#  11,
#  8,
#  11,
#  2,
#  9,
#  8,
#  9,
#  9,
#  10,
#  9,
#  9,
#  8,
#  11,
#  10,
#  3,
#  8,
#  10,
#  10,
#  8,
#  8,
#  11,
#  8,
#  9,
#  9,
#  9,
#  10,
#  8,
#  5,
#  8,
#  10,
#  8,
#  9,
#  11,
#  8,
#  11,
#  11,
#  11,
#  9,
#  10,
#  8,
#  10,
#  10,
#  8,
#  2,
#  9,
#  11,
#  10,
#  8,
#  8,
#  9,
#  11,
#  11,
#  11,
#  8,
#  9,
#  10,
#  8,
#  11,
#  9,
#  8,
#  10,
#  9,
#  9,
#  9,
#  8,
#  9,
#  9,
#  8,
#  8,
#  8,
#  11,
#  8,
#  7,
#  10,
#  7,
#  9,
#  11,
#  8,
#  9,
#  7,
#  8,
#  6,
#  8,
#  9,
#  3,
#  11,
#  3,
#  7,
#  9,
#  10,
#  9,
#  10,
#  11,
#  11,
#  5,
#  8,
#  11,
#  10,
#  9,
#  9,
#  8,
#  8,
#  8,
#  7,
#  9,
#  11,
#  10,
#  11,
#  4,
#  11,
#  8,
#  8,
#  9,
#  8,
#  10,
#  8,
#  10,
#  8,
#  9,
#  10,
#  9,
#  10,
#  10,
#  8,
#  9,
#  8,
#  9,
#  10,
#  4,
#  8,
#  9,
#  3,
#  10,
#  11,
#  11,
#  10,
#  5,
#  10,
#  10,
#  8,
#  7,
#  8,
#  8,
#  10,
#  8,
#  8,
#  9,
#  9,
#  9,
#  9,
#  20,
#  17,
#  17,
#  12,
#  17,
#  4,
#  15,
#  14,
#  3,
#  12,
#  16,
#  3,
#  14,
#  12,
#  11,
#  17,
#  9,
#  17,
#  8,
#  17,
#  3,
#  5,
#  9,
#  15,
#  15,
#  10,
#  14,
#  11,
#  14,
#  2,
#  5,
#  7,
#  12,
#  5,
#  7,
#  4,
#  11,
#  12,
#  13,
#  13,
#  15,
#  15,
#  11,
#  3,
#  10,
#  6,
#  6,
#  10,
#  10,
#  10,
#  15,
#  10,
#  12,
#  15,
#  16,
#  9,
#  9,
#  13,
#  11,
#  9,
#  10,
#  14,
#  16,
#  13,
#  4,
#  14,
#  9,
#  8,
#  11,
#  8,
#  10,
#  13,
#  7,
#  11,
#  13,
#  16,
#  13,
#  8,
#  15,
#  10,
#  9,
#  8,
#  7,
#  6,
#  5,
#  11,
#  8,
#  13,
#  10,
#  4,
#  8,
#  4,
#  8,
#  9,
#  8,
#  4,
#  8,
#  8,
#  9,
#  7,
#  12,
#  9,
#  8,
#  14,
#  9,
#  10,
#  10,
#  12,
#  10,
#  9,
#  10,
#  9,
#  8,
#  7,
#  14,
#  14,
#  8,
#  5,
#  9,
#  10,
#  10,
#  9,
#  5,
#  11,
#  8,
#  10,
#  3,
#  4,
#  8,
#  10,
#  9,
#  13,
#  9,
#  11,
#  18,
#  12,
#  10,
#  7,
#  15,
#  3,
#  11,
#  9,
#  17,
#  10,
#  13,
#  9,
#  5,
#  5,
#  4,
#  6,
#  9,
#  14,
#  7,
#  9,
#  11,
#  10,
#  11,
#  9,
#  6,
#  9,
#  8,
#  10,
#  13,
#  15,
#  8,
#  9,
#  13,
#  8,
#  11,
#  14,
#  11,
#  10,
#  8,
#  8,
#  10,
#  10,
#  8,
#  7,
#  13,
#  9,
#  10,
#  12,
#  9,
#  9,
#  11,
#  11,
#  6,
#  10,
#  9,
#  11,
#  9,
#  9,
#  11,
#  10,
#  12,
#  9,
#  10,
#  12,
#  11,
#  5,
#  11,
#  17,
#  12,
#  15,
#  16,
#  13,
#  3,
#  7,
#  15,
#  5,
#  17,
#  13,
#  16,
#  10,
#  15,
#  4,
#  12,
#  4,
#  3,
#  15,
#  15,
#  15,
#  13,
#  16,
#  13,
#  14,
#  14,
#  14,
#  15,
#  16,
#  16,
#  17,
#  14,
#  15,
#  17,
#  16,
#  12,
#  16,
#  15,
#  12,
#  7,
#  13,
#  14,
#  14,
#  15,
#  3,
#  6,
#  15,
#  12,
#  7,
#  14,
#  7,
#  15,
#  4,
#  15,
#  12,
#  15,
#  15,
#  16,
#  16,
#  13,
#  14,
#  14,
#  15,
#  4,
#  13,
#  15,
#  13,
#  12,
#  12,
#  16,
#  17,
#  15,
#  16,
#  16,
#  16,
#  14,
#  12,
#  12,
#  12,
#  16,
#  16,
#  14,
#  15,
#  15,
#  6,
#  14,
#  13,
#  12,
#  15,
#  3,
#  12,
#  14,
#  17,
#  10,
#  16,
#  7,
#  16,
#  13,
#  12,
#  17,
#  13,
#  2,
#  14,
#  17,
#  15,
#  12,
#  16,
#  17,
#  12,
#  16,
#  16,
#  14,
#  12,
#  13,
#  15,
#  12,
#  12,
#  12,
#  13,
#  5,
#  12,
#  16,
#  13,
#  16,
#  13,
#  12,
#  14,
#  15,
#  14,
#  9,
#  13,
#  15,
#  16,
#  12,
#  13,
#  14,
#  15,
#  12,
#  15,
#  15,
#  17,
#  16,
#  15,
#  12,
#  15,
#  13,
#  13,
#  16,
#  10,
#  13,
#  15,
#  14,
#  16,
#  13,
#  12,
#  14,
#  15,
#  12,
#  17,
#  6,
#  16,
#  12,
#  14,
#  13,
#  14,
#  13,
#  12,
#  13,
#  10,
#  16,
#  15,
#  5,
#  11,
#  13,
#  16,
#  14,
#  12,
#  15,
#  16,
#  7,
#  17,
#  15,
#  16,
#  17,
#  13,
#  12,
#  13,
#  4,
#  16,
#  15,
#  12,
#  16,
#  12,
#  17,
#  16,
#  13,
#  9,
#  16,
#  13,
#  13,
#  2,
#  4,
#  17,
#  14,
#  13,
#  17,
#  15,
#  17,
#  9,
#  13,
#  12,
#  15,
#  15,
#  13,
#  16,
#  13,
#  17,
#  12,
#  15,
#  17,
#  13,
#  12,
#  15,
#  13,
#  13,
#  12,
#  14,
#  13,
#  17,
#  11,
#  16,
#  16,
#  12,
#  7,
#  13,
#  14,
#  10,
#  13,
#  17,
#  15,
#  5,
#  12,
#  7,
#  4,
#  12,
#  13,
#  15,
#  12,
#  17,
#  13,
#  13,
#  12,
#  15,
#  13,
#  12,
#  15,
#  15,
#  13,
#  17,
#  16,
#  13,
#  15,
#  14,
#  15,
#  13,
#  12,
#  12,
#  14,
#  16,
#  15,
#  12,
#  17,
#  15,
#  13,
#  14,
#  15,
#  10,
#  13,
#  13,
#  13,
#  13,
#  13,
#  17,
#  14,
#  16,
#  12,
#  12,
#  9,
#  5,
#  15,
#  14,
#  13,
#  15,
#  12,
#  12,
#  12,
#  15,
#  12,
#  12,
#  7,
#  13,
#  17,
#  12,
#  13,
#  15,
#  12,
#  5,
#  3,
#  3,
#  13,
#  12,
#  9,
#  15,
#  12,
#  15,
#  5,
#  16,
#  12,
#  12,
#  12,
#  12,
#  12,
#  15,
#  16,
#  13,
#  15,
#  6,
#  17,
#  12,
#  13,
#  15,
#  17,
#  15,
#  14,
#  13,
#  7,
#  12,
#  4,
#  9,
#  16,
#  17,
#  6,
#  15,
#  14,
#  6,
#  17,
#  13,
#  15,
#  16,
#  13,
#  12,
#  12,
#  17,
#  14,
#  16,
#  14,
#  12,
#  8,
#  10,
#  3,
#  14,
#  13,
#  14,
#  16,
#  13,
#  15,
#  13,
#  15,
#  14,
#  7,
#  16,
#  2,
#  15,
#  9,
#  9,
#  6,
#  12,
#  13,
#  15,
#  13,
#  13,
#  14,
#  16,
#  16,
#  14,
#  11,
#  13,
#  15,
#  12,
#  16,
#  13,
#  13,
#  7,
#  6,
#  12,
#  16,
#  12,
#  12,
#  12,
#  15,
#  14,
#  17,
#  16,
#  14,
#  16,
#  12,
#  13,
#  17,
#  14,
#  13,
#  12,
#  14,
#  12,
#  4,
#  12,
#  17,
#  14,
#  17,
#  15,
#  17,
#  16,
#  15,
#  16,
#  13,
#  17,
#  6,
#  9,
#  15,
#  8,
#  17,
#  16,
#  17,
#  13,
#  13,
#  3,
#  12,
#  12,
#  14,
#  ...]

# %%
# Out:
# array([[-0.05196425, -0.11119605,  1.0417968 , ...,  2.60281328,
#         -1.98327783, -0.92686366],
#        [ 0.94589607, -0.75058415, -0.79426004, ...,  0.41139831,
#          0.88277695,  0.45908868],
#        [ 2.56976704, -0.67412361, -0.35723887, ...,  0.07543409,
#          0.54942243,  0.02074964],
#        ...,
#        [ 0.10565442, -1.04317779,  0.33991146, ...,  0.72611056,
#         -0.00575399,  0.20698523],
#        [-0.42645527, -1.66107771,  0.46212168, ..., -0.48419356,
#          1.48999011,  0.46971444],
#        [-0.47319654,  0.46891723,  0.07037226, ...,  0.22503128,
#         -1.02666071, -0.38592419]])

# %%
# create Prosit retention time predictor
model = PrositRetentionTimePredictor(seq_length=30)

# create the optimizer object
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

# compile the model  with the optimizer and the metrics we want to use, we can add our custom timedelta metric
model.compile(optimizer=optimizer,
              loss='mse',
              metrics=['mean_absolute_error', TimeDeltaMetric()])

# %%
# config the model
config = wandb.config
config.seq_length = 30
config.batch_size = BATCH_SIZE
config.val_ratio = 0.2
config.lr = 0.0001
config.optimizer = "adam"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b02e93721495> in <cell line: 2>()
#       1 # config the model
# ----> 2 config = wandb.config
#       3 config.seq_length = 30
#       4 config.batch_size = BATCH_SIZE
#       5 config.val_ratio = 0.2
#
# NameError: name 'wandb' is not defined

# %%
# train the model
history = model.fit(rtdata.train_data,
                    validation_data=rtdata.val_data,
                    epochs=2, callbacks=[WandbMetricsLogger(log_freq = "batch")] )
wandb.finish()
# Out:
# Epoch 1/2
# 17/17 [==============================] - 29s 1s/step - loss: 3546.3992 - mean_absolute_error: 48.9656 - timedelta: 58.5058 - val_loss: 1315.2650 - val_mean_absolute_error: 29.0293 - val_timedelta: 20.3434
# Epoch 2/2
# 17/17 [==============================] - 16s 960ms/step - loss: 3399.5618 - mean_absolute_error: 47.8536 - timedelta: 57.2616 - val_loss: 946.7090 - val_mean_absolute_error: 23.9561 - val_timedelta: 18.6724
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/batch_step</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>batch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/loss</td><td>▁▂▂▂▄▄▅▄▄▅▅▆▆▆▇██▁▂▂▂▃▄▅▄▄▅▅▅▆▆▇▇█</td></tr><tr><td>batch/mean_absolute_error</td><td>▁▂▂▃▄▅▅▅▅▆▆▆▆▇▇██▁▂▂▃▄▅▅▅▅▅▆▆▆▇▇██</td></tr><tr><td>batch/timedelta</td><td>▁▁▁▃▄▄▅▅▅▆▇▇▇▆▇██▁▁▁▃▄▄▅▅▅▆▇▇▇▆▇▇█</td></tr><tr><td>epoch/epoch</td><td>▁█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁</td></tr><tr><td>epoch/loss</td><td>█▁</td></tr><tr><td>epoch/mean_absolute_error</td><td>█▁</td></tr><tr><td>epoch/timedelta</td><td>█▁</td></tr><tr><td>epoch/val_loss</td><td>█▁</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>█▁</td></tr><tr><td>epoch/val_timedelta</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/batch_step</td><td>33</td></tr><tr><td>batch/learning_rate</td><td>0.0001</td></tr><tr><td>batch/loss</td><td>3399.56177</td></tr><tr><td>batch/mean_absolute_error</td><td>47.85365</td></tr><tr><td>batch/timedelta</td><td>57.26155</td></tr><tr><td>epoch/epoch</td><td>1</td></tr><tr><td>epoch/learning_rate</td><td>0.0001</td></tr><tr><td>epoch/loss</td><td>3399.56177</td></tr><tr><td>epoch/mean_absolute_error</td><td>47.85365</td></tr><tr><td>epoch/timedelta</td><td>57.26155</td></tr><tr><td>epoch/val_loss</td><td>946.70898</td></tr><tr><td>epoch/val_mean_absolute_error</td><td>23.9561</td></tr><tr><td>epoch/val_timedelta</td><td>18.67243</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_7</strong> at: <a href='https://wandb.ai/master_praktikum/retention_time_report/runs/nfezk00h' target="_blank">https://wandb.ai/master_praktikum/retention_time_report/runs/nfezk00h</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230713_140119-nfezk00h/logs</code>

# %%
ENTITY = wandb.apis.PublicApi().default_entity



pg_train = wr.PanelGrid(
    runsets=[
        wr.Runset(ENTITY, PROJECT),
    ],
    panels=[
        wr.LinePlot(x='Step', y=['batch/loss']),
        wr.LinePlot(x='Step', y=['batch/timedelta']),
        wr.LinePlot(x='Step', y=['batch/mean_absolute_error'])
    ]
)

pg_val = wr.PanelGrid(
    runsets=[
        wr.Runset(ENTITY, PROJECT),
    ],
    panels=[
        wr.LinePlot(x='Step', y=['epoch/val_loss']),
        wr.LinePlot(x='Step', y=['epoch/val_timedelta']),
        wr.LinePlot(x='Step', y=['epoch/val_mean_absolute_error'])
    ]
)

report.blocks = report.blocks[:1] +[wr.H1("Training metrics"), pg_train] + [wr.H1("Validation metrics"), pg_val] + report.blocks[1:]

report.save()
# Out:
# Report(project='retention_time_report', entity='master_praktikum', title='Retention time report_data', description='A first try creating a WANDB report using DLOmix', width='readable', blocks=[H1(text=['Training metrics']), PanelGrid(runsets=[Runset(entity='master_praktikum', project='retention_time_report', name='Run set', query='', filters={'$or': [{'$and': []}]}, order=['-CreatedTimestamp'])], panels=[LinePlot(x='Step', y=['batch/loss']), LinePlot(x='Step', y=['batch/timedelta']), LinePlot(x='Step', y=['batch/mean_absolute_error'])]), H1(text=['Validation metrics']), PanelGrid(runsets=[Runset(entity='master_praktikum', project='retention_time_report', name='Run set', query='', filters={'$or': [{'$and': []}]}, order=['-CreatedTimestamp'])], panels=[LinePlot(x='Step', y=['epoch/val_loss']), LinePlot(x='Step', y=['epoch/val_timedelta']), LinePlot(x='Step', y=['epoch/val_mean_absolute_error'])])])

# %%
# Histogramm over peptide lengths

# Histogramm over retention times
